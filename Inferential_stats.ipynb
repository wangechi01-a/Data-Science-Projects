# %%
import pandas as pd 
import numpy as np
import scipy.stats as stats

# %%
data  = pd.read_csv('e-commerce.csv')
data.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
#Dropping missing values
data = data.dropna(subset=['Satisfaction Level'])
data.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          0
# dtype: int64

# %%
data.shape
# Out:
# (348, 11)

# %%
data.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %% [markdown]
# H0 - All membership type mean spend is the same
#
# H1 - There is a difference in mean spend of membership type

# %% [markdown]
# Anova hypothesis testing

# %%
from scipy.stats import f_oneway
#filtering the columns of membership types with the total spend column
gold_type = data[data['Membership Type'] == 'Gold']['Total Spend']
silver_type = data[data['Membership Type'] == 'Silver']['Total Spend']
bronze_type = data[data['Membership Type'] == 'Bronze']['Total Spend']
 
 #using one way ANOVA test to verify our hypothesis
anova_statistic,anova_p_value=f_oneway(gold_type,silver_type,bronze_type)
print(anova_p_value)
alpha=0.05
if anova_p_value>alpha:
    print("null hypothesis fails to be rejected thus there is no difference between the means of the membership type spending")
else:
    print("null hypothesis is rejected therefore there is a significant difference in the mean spending of the membership types")
# Out:
# 3.744768965836192e-199
# null hypothesis is rejected therefore there is a significant difference in the mean spending of the membership types

# %%
data.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level'],
#       dtype='object')

# %% [markdown]
# Chi-square

# %% [markdown]
# H0 - Level of satisfaction doesn't differs by gender
#
# H1 - Level of satisfaction differ by gender

# %%
data['sex'] = data['Gender'].apply(lambda x: 0 if x=='Female' else 1 )
data['satisfaction_level_new'] = data['Satisfaction Level'].apply(lambda x: 0 if x=='Satisfied' else (1 if x=='Neutral' else 2))
data.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level  sex  satisfaction_level_new
# 0                        25          Satisfied    0                       0
# ...

# %%
from scipy.stats import chi2_contingency

alpha = 0.05

contigency_table = pd.crosstab(data['Satisfaction Level'], data['Gender'])

chi_statistic,pvalue, degree_of_freedom, expected = chi2_contingency(contigency_table)

print(chi_statistic)

print("The pvalue is:", pvalue)

if pvalue < alpha:
    print('Reject null hypothesis: There is a difference in satisfaction levels')
else:
    print("Fail to reject: Satisfaction level is the same")
# Out:
# 0.9046632461007731
# The pvalue is: 0.6361431750014872
# Fail to reject: Satisfaction level is the same

# %%
import mysql.connector
conn = mysql.connector.connect(host='localhost',password='Eu724700@',user='root', database = 'fraud_detection.creditcard')

if conn.is_connected():
   print("connection established...")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import mysql.connector
#       2 conn = mysql.connector.connect(host='localhost',password='Eu724700@',user='root', database = 'fraud_detection.creditcard')
#       4 if conn.is_connected():
#
# ModuleNotFoundError: No module named 'mysql'
